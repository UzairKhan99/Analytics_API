# %%
import requests
import httpx

# %%
path="/api/events"
base_url ="http://127.0.0.1:8002"
endpoints=f"{base_url}{path}"
endpoints
# Out:
# 'http://127.0.0.1:8002/api/events'

# %%
resposne=requests.get(endpoints)
